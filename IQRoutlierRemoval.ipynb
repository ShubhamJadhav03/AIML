# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamJadhav03/AIML/blob/main/IQRoutlierRemoval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("/content/height_weight.csv")

# %%
df.head()
# Out:
#   gender     height      weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (8,4)

# %%
plt.hist(df.height, bins = 20, rwidth = 0.8 )
plt.xlabel("Height")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(df.weight, bins = 20, rwidth = 0.8 )
plt.xlabel("weight")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# For Weight

# %%
Q1 = df.weight.quantile(0.25)
Q3 = df.weight.quantile(0.75)
Q1, Q3
# Out:
# (135.8180513055015, 187.16952486868348)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 51.35147356318197

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
df[(df.weight<lower_limit)|(df.weight>upper_limit)]
# Out:
#      gender     height      weight
# 2014   Male  78.998742  269.989699

# %% [markdown]
# For Height

# %%
Q1 = df.height.quantile(0.25)
Q3 = df.height.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 5.668641245615746

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
df[(df.height<lower_limit)|(df.height>upper_limit)]
# Out:
#       gender     height      weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 7294  Female  54.873728   78.606670
# 9285  Female  54.263133   64.700127
